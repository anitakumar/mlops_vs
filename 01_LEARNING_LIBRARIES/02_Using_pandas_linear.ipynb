# %%
import numpy as np
print(np.__version__)
# Out:
# 2.3.1

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
mtcarsdf= pd.read_csv('data/linear.csv')

# %%
mtcarsdf
# Out:
#    x   y
# 0  1   7
# 1  2   9
# 2  3  11
# 3  4  13
# 4  5  15

# %%
! pip install matplotlib

# %%
mtcarsdf.plot(x='x', y='y')
# Out:
# <Axes: xlabel='x'>

# %%
mtcarsdf.plot.scatter(x='x', y='y')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
mtcarsdf.plot.line(x='x', y='y')
# Out:
# <Axes: xlabel='x'>

# %%
# use scikit-learn to choose Regression algorithm in this case leinear.
from sklearn.linear_model import LinearRegression

# %%
mtcarsdf[['x']]
# Out:
#    x
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
model= LinearRegression()

# %%
model.fit(mtcarsdf[['x']],mtcarsdf[['y']])
# Out:
# LinearRegression()

# %%
model.score(mtcarsdf[['x']],mtcarsdf[['y']])
# Out:
# 1.0

# %%
model.coef_
# Out:
# array([[2.]])

# %%
model.intercept_
# Out:
# array([5.])

# %%
#now predict
model.predict(np.array([[100]]))
# Out:
# C:\Users\anita\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[205.]])
