# %%
import numpy as np
print(np.__version__)
# Out:
# 2.3.1

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
mtcarsdf= pd.read_csv('data/mtcars.csv')

# %%
mtcarsdf
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
selected_mtcarsdf= mtcarsdf[['model','mpg','cyl','disp','hp','gear','carb']]

# %%
selected_mtcarsdf
# Out:
#                   model   mpg  cyl   disp   hp  gear  carb
# 0             Mazda RX4  21.0    6  160.0  110     4     4
# 1         Mazda RX4 Wag  21.0    6  160.0  110     4     4
# 2            Datsun 710  22.8    4  108.0   93     4     1
# 3        Hornet 4 Drive  21.4    6  258.0  110     3     1
# 4     Hornet Sportabout  18.7    8  360.0  175     3     2
# 5               Valiant  18.1    6  225.0  105     3     1
# 6            Duster 360  14.3    8  360.0  245     3     4
# 7             Merc 240D  24.4    4  146.7   62     4     2
# 8              Merc 230  22.8    4  140.8   95     4     2
# 9              Merc 280  19.2    6  167.6  123     4     4
# 10            Merc 280C  17.8    6  167.6  123     4     4
# 11           Merc 450SE  16.4    8  275.8  180     3     3
# 12           Merc 450SL  17.3    8  275.8  180     3     3
# 13          Merc 450SLC  15.2    8  275.8  180     3     3
# 14   Cadillac Fleetwood  10.4    8  472.0  205     3     4
# ...

# %%
selected_mtcarsdf.head(5)
# Out:
#                model   mpg  cyl   disp   hp  gear  carb
# 0          Mazda RX4  21.0    6  160.0  110     4     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110     4     4
# 2         Datsun 710  22.8    4  108.0   93     4     1
# 3     Hornet 4 Drive  21.4    6  258.0  110     3     1
# 4  Hornet Sportabout  18.7    8  360.0  175     3     2

# %%
selected_mtcarsdf.tail(5)
# Out:
#              model   mpg  cyl   disp   hp  gear  carb
# 27    Lotus Europa  30.4    4   95.1  113     5     2
# 28  Ford Pantera L  15.8    8  351.0  264     5     4
# 29    Ferrari Dino  19.7    6  145.0  175     5     6
# 30   Maserati Bora  15.0    8  301.0  335     5     8
# 31      Volvo 142E  21.4    4  121.0  109     4     2

# %%
selected_mtcarsdf.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'gear', 'carb'], dtype='object')

# %%
selected_mtcarsdf.dtypes
# Out:
# model     object
# mpg      float64
# cyl        int64
# disp     float64
# hp         int64
# gear       int64
# carb       int64
# dtype: object

# %%
#plot some graphs
# !pip install matplotlib

# %%
#using plots - label goes in y axis
selected_mtcarsdf.plot(x='cyl', y='hp')
# Out:
# <Axes: xlabel='cyl'>

# %%
#use scatter plot
selected_mtcarsdf.plot.scatter(x='cyl',y='hp')
# Out:
# <Axes: xlabel='cyl', ylabel='hp'>
